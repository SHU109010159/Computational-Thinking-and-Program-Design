# %% [markdown]
# <a href="https://colab.research.google.com/github/SHU109010159/Computational-Thinking-and-Program-Design/blob/main/A109010159_%E5%BB%96%E5%A6%82%E7%A9%8E_%E6%9C%9F%E6%9C%AB%E5%A0%B1%E5%91%8A_%E6%B2%89%E7%9D%A1%E4%B9%8B%E6%A3%AE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("我是一名帝國的頭號龍騎士")
print("現在我有個任務，就是去拯救我的摯愛，卡蓮公主，她被異邦的人綁走了。")
print("我會失敗嗎?")
print("我不知道，但只要是為了她...我就能不顧一切!")
print("我走進了眼前那片最深邃的森林裡。")

your_choice = input("yes or no \
yes = 繼續向前 no = 停留此地")

if your_choice == "yes":
  print("我拿到了前所未有的神劍迅龍太刀。")
  print("我的眼前是一名男子。")
  print("他手持雙刀，正在與魔物對戰。")
  print("我，神勇的騎士，該不該幫他呢該不該幫他呢?")   
  
  help_him = input("yes or no \
  yes = 有可能會受傷 no = 我只是個過客...")

  if help_him =="yes":
    print("魔物被我們殺死了。")
    print("交流了一下，我們變成朋友。")
    print("我告訴他我的目的與任務。")
    print("他被我的目的嚇到了。")
    print("但他臉上的笑容從未消失過。")    
    print("我問他要不要加入我的行動。")
    print("「你都幫我殺死魔物了，哪有理由不幫忙啊?」")
    print("「這條項鍊給你，是我部落的守護靈碎石。」")
    print("「其實我曾經是個戰士，不過...。」")
    print("我沒有追問下去，當務之急是要拯救我的摯愛。")
    print("他臉上的認真與熱情讓我十分感動。")
    print("「我是阿卡曼一族的戰士，我叫里維，不過幾年前被鄰國的暴君屠村了。")
    print("「剩我一個人跟姊姊相依為命。")
    print("聽了他的故事，我知道我其實並不可憐，我有家有國還有最愛的公主。")
    print("「騎士大人，別讓我失望。」")
    print("絕對不會，為了你還有卡蓮，我會奮不顧身。")
    print("...等等!")
    print("一隻佈滿獠牙的怪物出現在我們眼前，體型像龍一般。")
    print("我可是龍騎士，我不能認輸，但牠的體型太大了...。")

    our_choice = input("fight or run \
    fight = 牠有機率會死 run = 我們會被追殺而死 ")

    if our_choice =="fight":
      print("殺啊啊啊啊啊啊啊!")
      print("怪物慘死在我們手中。")
      print("離公主又更近了一步。")
      print("「再往前是尤彌的地盤。」里維說道")
      print("尤彌，森林裡最難搞的王，傳說兩千多年前就在這裡，不老不死，也沒有性別。")
      print("「它不會讓我們過的對吧?」")
      print("里維看起來很失落，但為了卡蓮我是不會放棄的!")
      print("我們走進了森林的最深處，白霧升起，看不見遠方的風景。")
      print("想過此地，取吾之首。")
      print("尤彌不是人類，所有人都知道它的弱點，但吾國沒有人能成功瓦解這個異邦的守護靈。")
      print("弱點就在眉心中間那顆紅色的寶石")
      print("想成為英雄就趁這次了。")

      attack_yumi = input("try or not \
      try = 可能會失敗 not = 什麼都得不到")

      if attack_yumi =="try":
        print("紅色寶石的強大光芒粉碎了里維的雙刀。")
        print("「把我給你的守護靈拿出來!」")
        print("此時尤彌強大的雙爪朝我揮來，我該逃還是拿出守護靈?")

        my_choice = input("take or run \
        take = 有機率受傷 run = 有機率躲過攻擊")

        if my_choice =="run":
          print("好險我躲過了攻擊，也成功砍傷尤彌一刀。")
          print("尤彌怒吼著，我拿起了藍色的守護靈項鍊朝紅色寶石丟去。")
          print("尤彌痛苦的大叫，藍色與紅色的光交織在一起。")
          print("里維奮不顧身用雙刃展下尤彌的首級。")
          print("頓時天崩地裂，我們踩著落石向異國奔去。")
          print("我站在高處看著敵方帝國，卡蓮一定在那座塔裡面!")
          print("我乘著龍帶著里維向塔的方向攻擊。")
          print("塔的側邊裂開，卡蓮並不在裡面。於是我直接朝皇宮進攻")
          print("「我就知道你會來救我!」")
          print("是卡蓮，但她身上的鎖鏈是尤彌分裂的石頭構成的，一般武器斬不斷，而且會吸血。」")
          print("我叫飛龍離去，站在卡蓮面前，想起了阿卡曼一族的守護靈，可惜剛剛與尤彌激戰用完了。")
          print("到底該怎麼辦...。")
          print("「騎士大人，請用我的骨頭。」")
          print("「阿卡曼一族之所以存在就是為了平衡彼此的力量。」")
          print("「我不行!」我怒吼著，但看到卡蓮痛苦的樣子又猶豫不決。")
          
          levi_bone = input("kill or not kill \
          kill = 里維會死 not kill = 卡蓮會死")

          if levi_bone == "kill":
            print("此時你陷入兩難，但你還是選擇了里維。")
            print("要讓局勢完美真不容易。")
            print("「里維，我對不起你。」")
            print("「這就是我的命運。」")
            print("「等一下，等一下唷!」白髮蒼蒼的老人在旁邊喊道")
            print("「我老人家看著小夥你都被感動了唷!」")
            print("老先知賽維大叔的靈魂出現在我面前。")
            print("「我被一個問題困擾很久了，你們幫幫我，我就用魔力試試看解除公主的詛咒唷。」")
            print("「老夫問了啊，請問主動愛人與被愛，你選擇哪一個呢?」")
            print("「我...我不知道。」")

            my_choice = input("love or loved \
            love = ? loved = ?")


            
            if my_choice == "love":
             print("「原來如此，你擁有的是愛人的力量。」")
             print("「老人家我好感動啊!你為了守護身邊的同伴，不放棄任何一個人。」")
             print("「那我就幫助你解開所有人的枷鎖吧!」")
             print("一道藍色的光從老先知身上散發出來，公主的枷鎖逐漸裂開，里維的胸口前多了一個印記。")
             print("「這個印記...?」")
             print("「少年唷，你不惜犧牲生命也要拯救勇者的心感動了整個森林」塞維指著遠方烏暗的森林")
             print("黑暗的森林不再黑暗，逐漸充滿碧色的光芒，所有枯木都恢復了生靈。")
             print("「老人家我的任務告此結束，勇者，帶著她回到你的國度吧!」")
             print("老先知化作光，消失在我們眼前。」")
             print("「...我會永遠記得你的，老先知。」")
             print("「卡蓮!」我緊緊擁抱著她")
             print("「我以為我要死了...還好我相信你的力量!」卡蓮流著淚。")
             print("三個人相視而笑，我召喚龍帶我們回到國度。")
             print("故事結束了，這就是我的故事，也是你的故事。")
             print("謝謝你讓我的故事有個好的結局。")
             print("-------------GOOD END-------------")

            elif my_choice == ("loved"):
              print("「被愛的人，這是只想享受付出，無視他人感受的意思嗎?」老先知看起來有點生氣。")
              print("「我不是那個意思...。」")
              print("「你既然知道答案了為什麼還要問我?」我憤怒地拿著劍指向塞維")
              print("老先知沒有得到滿意的答案，卡蓮的血被逐漸吸乾。")
              print("該死，我怎麼會犯這種錯誤...。")
              print("里維活了下來，卡蓮在你眼前死去")
              print("享受被愛或許可以是一種選擇，但也驗證了身邊的人會受傷害。")
              print("-------------NORMAL END-------------")


             



          elif levi_bone == "not kill":
            print("卡蓮的血被枷鎖一點一滴地吸光，最後倒下而死")
            print("你一無所有。")  

             



        elif my_choice =="take":
          print("眼前一片鮮紅，我死在尤彌爪下，最後只能聽見里維的哭喊聲。")  

      elif attack_yumi =="not":
        print("被困在這座森林一輩子。")
        print("卡蓮...。")  






    elif our_choice =="run":
      print("里維死在龍的追輾之下，我也慘死魔物口中。")
      












     













  elif help_him =="no":
    print("男人死了。")
    print("我從此活在罪惡感之中。")

   
  
  











elif your_choice == "no":
  print("卡蓮死了。")
  print("我失去摯愛。")
  print("永遠...永遠...。")
# Out:
# 我是一名帝國的頭號龍騎士
# 現在我有個任務，就是去拯救我的摯愛，卡蓮公主，她被異邦的人綁走了。
# 我會失敗嗎?
# 我不知道，但只要是為了她...我就能不顧一切!
# 我走進了眼前那片最深邃的森林裡。
# yes or no yes = 繼續向前 no = 停留此地no
# 卡蓮死了。
# 我失去摯愛。
# 永遠...永遠...。
